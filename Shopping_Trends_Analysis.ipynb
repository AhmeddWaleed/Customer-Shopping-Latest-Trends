# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('shopping_trends.csv')
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# ### Exploring Data

# %%
df.head(10)
# Out:
#    Customer ID  Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse     Clothing                     53
# 1            2   19   Male        Sweater     Clothing                     64
# 2            3   50   Male          Jeans     Clothing                     73
# 3            4   21   Male        Sandals     Footwear                     90
# 4            5   45   Male         Blouse     Clothing                     49
# 5            6   46   Male       Sneakers     Footwear                     20
# 6            7   63   Male          Shirt     Clothing                     85
# 7            8   27   Male         Shorts     Clothing                     34
# 8            9   26   Male           Coat    Outerwear                     97
# 9           10   57   Male        Handbag  Accessories                     31
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# ...

# %%
df.shape
# Out:
# (3900, 19)

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898    False
# 3899    False
# Length: 3900, dtype: bool

# %%
print("Count of duplicates:", df.duplicated().sum())
# Out:
# Count of duplicates: 0

# %% [markdown]
# ### Analyzing and Visualizing Data

# %%
df['Customer ID'].nunique()
# Out:
# 3900

# %%
# Total Spent by Customers

df.groupby("Customer ID")["Purchase Amount (USD)"].sum().sort_values(ascending=False)
# Out:
# Customer ID
# 1480    100
# 1457    100
# 1592    100
# 2072    100
# 1422    100
#        ...
# 295      20
# 3794     20
# 3881     20
# 587      20
# 3855     20
# Name: Purchase Amount (USD), Length: 3900, dtype: int64

# %%
# Gender Distribution

Gender_Distribution = df["Gender"].value_counts()
Gender_Distribution
# Out:
# Gender
# Male      2652
# Female    1248
# Name: count, dtype: int64

# %%
plt.pie(Gender_Distribution, labels=Gender_Distribution.index , autopct='%.1f%%', startangle=90 , colors=['#727bf7' , '#da87ed']  )
plt.title("Gender Distribution")
plt.legend(labels=Gender_Distribution.index ,loc='upper right' )
plt.show()

# %%
# Subscription Distribution 

Subscription_Distribution = df["Subscription Status"].value_counts()
Subscription_Distribution
# Out:
# Subscription Status
# No     2847
# Yes    1053
# Name: count, dtype: int64

# %%
plt.pie(Subscription_Distribution, labels=Subscription_Distribution.index, startangle=90 , colors=['#faae57' , '#9ef763'], autopct='%.1f%%')
plt.title('Subscription Distribution')
plt.legend(labels=Subscription_Distribution.index , loc='upper right')
plt.show()

# %%
# Customer Count by Gender and Subscription Status

df.pivot_table(index="Gender",columns="Subscription Status",values="Customer ID",aggfunc="count",fill_value=0)
# Out:
# Subscription Status    No   Yes
# Gender
# Female               1248     0
# Male                 1599  1053

# %%
# Total Sales by Category

Total_Sales_by_Category = df.groupby("Category")["Purchase Amount (USD)"].sum().sort_values( ascending=False)
Total_Sales_by_Category
# Out:
# Category
# Clothing       104264
# Accessories     74200
# Footwear        36093
# Outerwear       18524
# Name: Purchase Amount (USD), dtype: int64

# %%
plt.pie(Total_Sales_by_Category , labels=Total_Sales_by_Category.index , startangle=90 , autopct='%.1f%%' 
        , colors = [ '#3593f2' , '#57a8fa'  , '#3cc9f0' , '#84edf5'])
plt.legend( labels=Total_Sales_by_Category.index , loc='upper right', bbox_to_anchor=(1.5, 1))
plt.title('Total Sales by Category')
plt.show()

# %%
# Quantity by Category

Quantity_by_Category = df["Category"].value_counts().sort_values(ascending=False)
Quantity_by_Category
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(5,5))
bars =plt.bar(Quantity_by_Category.index , Quantity_by_Category.values , color= '#95f542' , width=0.4)
plt.title('Quantity by Category')
plt.xlabel('Category')
plt.ylabel('Quantity')
ax.spines[['right' , 'top']].set_visible(False)
plt.bar_label(bars, fmt='%.0f', padding=3)
plt.show()

# %%
# Total Sales by Items

Total_Sales_by_Items = df.groupby("Item Purchased")["Purchase Amount (USD)"].sum().sort_values(ascending=False)
Total_Sales_by_Items
# Out:
# Item Purchased
# Blouse        10410
# Shirt         10332
# Dress         10320
# Pants         10090
# Jewelry       10010
# Sunglasses     9649
# Belt           9635
# Scarf          9561
# Sweater        9462
# Shorts         9433
# Skirt          9402
# Hat            9375
# Coat           9275
# Socks          9252
# Jacket         9249
# T-shirt        9248
# Shoes          9240
# Sandals        9200
# Boots          9018
# Handbag        8857
# Hoodie         8767
# Backpack       8636
# Sneakers       8635
# Gloves         8477
# Jeans          7548
# Name: Purchase Amount (USD), dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,8))
bars = plt.barh(Total_Sales_by_Items.index, Total_Sales_by_Items.values, color='#5da9f5')
plt.ylabel("Items")
plt.xlabel('Total Sales')
plt.title("Total Sales by Item")
ax.spines[['right' , 'top']].set_visible(False)
plt.bar_label(bars, fmt='%.0f', padding=3)
plt.show()

# %%
# Quantity by Items

Quantity_by_Items = df["Item Purchased"].value_counts().sort_values(ascending=False)
Quantity_by_Items
# Out:
# Item Purchased
# Blouse        171
# Pants         171
# Jewelry       171
# Shirt         169
# Dress         166
# Sweater       164
# Jacket        163
# Coat          161
# Sunglasses    161
# Belt          161
# Sandals       160
# Socks         159
# Skirt         158
# Scarf         157
# Shorts        157
# Hat           154
# Handbag       153
# Hoodie        151
# Shoes         150
# T-shirt       147
# Sneakers      145
# Boots         144
# Backpack      143
# Gloves        140
# Jeans         124
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,8))
bars = plt.barh(Quantity_by_Items.index, Quantity_by_Items.values, color='orange')
plt.ylabel("Items")
plt.xlabel("Quantity")
plt.title("Quantity by Items")
ax.spines[['right' , 'top']].set_visible(False)
plt.bar_label(bars, fmt='%.0f', padding=3)
plt.show()

# %%
# Total Sales by Category and Items

df.groupby(["Category" , "Item Purchased"])["Purchase Amount (USD)"].sum().sort_values(ascending=False)
# Out:
# Category     Item Purchased
# Clothing     Blouse            10410
#              Shirt             10332
#              Dress             10320
#              Pants             10090
# Accessories  Jewelry           10010
#              Sunglasses         9649
#              Belt               9635
#              Scarf              9561
# Clothing     Sweater            9462
#              Shorts             9433
#              Skirt              9402
# Accessories  Hat                9375
# Outerwear    Coat               9275
# Clothing     Socks              9252
# Outerwear    Jacket             9249
# Clothing     T-shirt            9248
# Footwear     Shoes              9240
#              Sandals            9200
#              Boots              9018
# Accessories  Handbag            8857
# Clothing     Hoodie             8767
# Accessories  Backpack           8636
# Footwear     Sneakers           8635
# Accessories  Gloves             8477
# ...

# %%
# Total Sales by Location

Total_Sales_by_Location = df.groupby("Location")["Purchase Amount (USD)"].sum().sort_values(ascending=False)
Total_Sales_by_Location
# Out:
# Location
# Montana           5784
# Illinois          5617
# California        5605
# Idaho             5587
# Nevada            5514
# Alabama           5261
# New York          5257
# North Dakota      5220
# West Virginia     5174
# Nebraska          5172
# New Mexico        5014
# Minnesota         4977
# Pennsylvania      4926
# Mississippi       4883
# Alaska            4867
# Vermont           4860
# Louisiana         4848
# Virginia          4842
# Arkansas          4828
# Maryland          4795
# Tennessee         4772
# Delaware          4758
# North Carolina    4742
# Texas             4712
# Missouri          4691
# Indiana           4655
# Ohio              4649
# Georgia           4645
# Washington        4623
# Michigan          4533
# Utah              4443
# South Carolina    4439
# Kentucky          4402
# Maine             4388
# Massachusetts     4384
# Oklahoma          4376
# Arizona           4326
# Wyoming           4309
# Oregon            4243
# ...

# %%
fig, ax = plt.subplots(figsize=(8,10))
bars = plt.barh(Total_Sales_by_Location.index, Total_Sales_by_Location.values, color='#5ad5fa')
plt.ylabel("Location")
plt.xlabel("Total Sales")
plt.title("Total Sales by Location")
ax.spines[['right' , 'top']].set_visible(False)
plt.bar_label(bars, fmt='%.0f', padding=3)
plt.show()

# %%
# Total Sales by Location and Category

df.pivot_table(index="Location", columns="Category", values="Purchase Amount (USD)", aggfunc="sum", fill_value=0 )
# Out:
# Category        Accessories  Clothing  Footwear  Outerwear
# Location
# Alabama                1576      2334       914        437
# Alaska                 1719      2229       693        226
# Arizona                1270      2129       471        456
# Arkansas               1555      2413       589        271
# California             1845      2740       662        358
# Colorado               1454      1748       654        366
# Connecticut            1334      1905       589        398
# Delaware               1486      2336       769        167
# Florida                1232      1680       434        452
# Georgia                1389      2336       827         93
# Hawaii                 1017      1773       365        597
# Idaho                  1769      2472       686        660
# Illinois               1854      2508       665        590
# Indiana                1328      2206       670        451
# Iowa                   1490      1410       863        438
# ...

# %%
# Customer Count by Location

Customer_Count_by_Location = df.groupby("Location")["Customer ID"].count().sort_values(ascending=False)
Customer_Count_by_Location
# Out:
# Location
# Montana           96
# California        95
# Idaho             93
# Illinois          92
# Alabama           89
# Minnesota         88
# Nebraska          87
# Nevada            87
# New York          87
# Delaware          86
# Maryland          86
# Vermont           85
# Louisiana         84
# North Dakota      83
# Missouri          81
# West Virginia     81
# New Mexico        81
# Mississippi       80
# Arkansas          79
# Georgia           79
# Indiana           79
# Kentucky          79
# North Carolina    78
# Connecticut       78
# Tennessee         77
# Ohio              77
# Texas             77
# Virginia          77
# Maine             77
# South Carolina    76
# Wisconsin         75
# Oklahoma          75
# Colorado          75
# Pennsylvania      74
# Oregon            74
# Michigan          73
# Washington        73
# Massachusetts     72
# Alaska            72
# Wyoming           71
# Utah              71
# New Hampshire     71
# South Dakota      70
# ...

# %%
fig , ax = plt.subplots(figsize=(8,10)) 
bars = plt.barh(Customer_Count_by_Location.index, Customer_Count_by_Location.values , color='#ba3bf5')
plt.xlabel("Location")
plt.ylabel("Customer Count")
plt.title("Customer Count by Location")
ax.spines[['right', 'top']].set_visible(False)
plt.bar_label(bars, fmt='%.0f', padding=3)
plt.show()

# %%
# Total Sales by Season

Total_Sales_by_Season = df.groupby("Season")["Purchase Amount (USD)"].sum().sort_values(ascending=False)
Total_Sales_by_Season
# Out:
# Season
# Fall      60018
# Spring    58679
# Winter    58607
# Summer    55777
# Name: Purchase Amount (USD), dtype: int64

# %%
plt.pie(Total_Sales_by_Season, labels=Total_Sales_by_Season.index, startangle=90 ,colors=['#a8f57f' , '#f7b140', '#6cc7f5', '#c375f0'], autopct='%.1f%%')
plt.title("Total Sales by Season")
plt.legend(labels=Total_Sales_by_Season.index , loc='upper right', bbox_to_anchor=(1.3, 1))
plt.show()

# %%
# Customer Count by Season

Customer_Count_by_Season = df.groupby("Season")["Customer ID"].count().sort_values(ascending=False)
Customer_Count_by_Season
# Out:
# Season
# Spring    999
# Fall      975
# Winter    971
# Summer    955
# Name: Customer ID, dtype: int64

# %%
plt.pie(Customer_Count_by_Season, labels=Customer_Count_by_Season.index, startangle=90 , autopct='%.1f%%' 
        , colors = [ '#3593f2' , '#57a8fa'  , '#3cc9f0' , '#84edf5'])
plt.legend(labels=Customer_Count_by_Season.index , loc='upper right', bbox_to_anchor=(1.3,1))
plt.title("Customer Count by Season")
plt.show()

# %%
# Average Rating by Items

df.groupby("Item Purchased")["Review Rating"].mean().sort_values(ascending=False)
# Out:
# Item Purchased
# Gloves        3.864286
# Sandals       3.841250
# Boots         3.812500
# Hat           3.806494
# T-shirt       3.782993
# Skirt         3.782278
# Handbag       3.775163
# Sweater       3.767073
# Jacket        3.763190
# Belt          3.761491
# Sneakers      3.757931
# Jewelry       3.756140
# Dress         3.754819
# Backpack      3.752448
# Socks         3.750943
# Shoes         3.747333
# Sunglasses    3.744720
# Coat          3.730435
# Hoodie        3.719205
# Pants         3.718713
# Shorts        3.711465
# Scarf         3.700000
# Blouse        3.683626
# Jeans         3.648387
# Shirt         3.629586
# Name: Review Rating, dtype: float64

# %%
# Creating new column containing rating classification

df.loc[df["Review Rating"] <= 2.5, 'Level'] = 'Low'
df.loc[df["Review Rating"] > 2.5 , 'Level'] = 'Medium'
df.loc[df["Review Rating"] > 3.7 , 'Level'] = 'High'

# %%
# Favourite Color by Category

df.groupby("Category")["Color"].value_counts().sort_values(ascending=False)
# Out:
# Category   Color
# Clothing   Teal        84
#            Maroon      83
#            Black       81
#            Silver      80
#            Violet      79
#                        ..
# Outerwear  Charcoal    10
#            Red         10
#            Maroon       8
#            Orange       8
#            Peach        8
# Name: count, Length: 100, dtype: int64

# %%
# Favourite Size by Category

df.groupby("Category")["Size"].value_counts().sort_values(ascending=False)
# Out:
# Category     Size
# Clothing     M       778
# Accessories  M       562
# Clothing     L       481
# Accessories  L       307
# Clothing     S       284
# Footwear     M       267
# Accessories  S       230
# Clothing     XL      194
# Footwear     L       172
# Outerwear    M       148
# Accessories  XL      141
# Footwear     S        93
# Outerwear    L        93
# Footwear     XL       67
# Outerwear    S        56
#              XL       27
# Name: count, dtype: int64

# %%
# Transaction count by Payment Method

Transaction_count_by_Payment_Method = df["Payment Method"].value_counts()
Transaction_count_by_Payment_Method
# Out:
# Payment Method
# Credit Card      696
# Venmo            653
# Cash             648
# PayPal           638
# Debit Card       633
# Bank Transfer    632
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(5,5))
bars = plt.bar(Transaction_count_by_Payment_Method.index , Transaction_count_by_Payment_Method.values, color='green')
plt.title('Transaction count by Payment Method')
plt.xlabel('Payment Method')
plt.xticks(rotation=45)
plt.ylabel('Transaction count')
ax.spines[['top', 'right']].set_visible(False)
plt.bar_label(bars, fmt='%.0f', padding=2)
plt.show()

# %%
# Preferred Payment Method count

Preferred_Payment_Method_count = df["Preferred Payment Method"].value_counts()
Preferred_Payment_Method_count
# Out:
# Preferred Payment Method
# PayPal           677
# Credit Card      671
# Cash             670
# Debit Card       636
# Venmo            634
# Bank Transfer    612
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(5,5))
bars = plt.bar(Preferred_Payment_Method_count.index , Preferred_Payment_Method_count.values, color='blue')
plt.title('Preferred Payment Method count')
plt.xlabel('Preferred Payment Method')
plt.xticks(rotation=45)
plt.ylabel('count')
ax.spines[['top', 'right']].set_visible(False)
plt.bar_label(bars, fmt='%.0f', padding=2)
plt.show()

# %%
# Transaction count by Shipping Type

Transaction_count_by_Shipping_Type = df["Shipping Type"].value_counts()
Transaction_count_by_Shipping_Type
# Out:
# Shipping Type
# Free Shipping     675
# Standard          654
# Store Pickup      650
# Next Day Air      648
# Express           646
# 2-Day Shipping    627
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(5,5))
bars = plt.bar(Transaction_count_by_Shipping_Type.index , Transaction_count_by_Shipping_Type.values, color='orange')
plt.title('Transaction count by Shipping Type')
plt.xlabel('Shipping Type')
plt.xticks(rotation=45)
plt.ylabel('Transaction count')
ax.spines[['top', 'right']].set_visible(False)
plt.bar_label(bars, fmt='%.0f', padding=2)
plt.show()

# %%
# Discount Applied Distribution

Discount_Applied_Distribution = df["Discount Applied"].value_counts()
Discount_Applied_Distribution
# Out:
# Discount Applied
# No     2223
# Yes    1677
# Name: count, dtype: int64

# %%
plt.pie(Discount_Applied_Distribution, labels=Discount_Applied_Distribution.index, startangle=90 , autopct='%.1f%%' 
        , colors = [ '#3593f2', '#ecfaa0'])
plt.legend(labels=Discount_Applied_Distribution.index , loc='upper right')
plt.title("Discount Applied Distribution")
plt.show()

# %%
# promo code Distribution

promo_code_Distribution = df["Promo Code Used"].value_counts()
promo_code_Distribution
# Out:
# Promo Code Used
# No     2223
# Yes    1677
# Name: count, dtype: int64

# %%
plt.pie(promo_code_Distribution , labels=promo_code_Distribution .index, startangle=90 , autopct='%.1f%%' 
        , colors = [ '#f7b174', '#5fc2ed'])
plt.legend(labels=promo_code_Distribution .index , loc='upper right')
plt.title("promo code Distribution")
plt.show()

# %%
# Purchase Frequency Distribution

Purchase_Frequency_Distribution = df["Frequency of Purchases"].value_counts()
Purchase_Frequency_Distribution
# Out:
# Frequency of Purchases
# Every 3 Months    584
# Annually          572
# Quarterly         563
# Monthly           553
# Bi-Weekly         547
# Fortnightly       542
# Weekly            539
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(5,5))
bars = plt.bar(Purchase_Frequency_Distribution.index , Purchase_Frequency_Distribution.values, color='brown')
plt.title('Purchase Frequency Distribution')
plt.xlabel('Purchase Frequency')
plt.xticks(rotation=45)
plt.ylabel('count')
ax.spines[['top', 'right']].set_visible(False)
plt.bar_label(bars, fmt='%.0f', padding=2)
plt.show()

# %% [markdown]
# ### Exporting the data in CSV

# %%
df.to_csv('shopping_trends_analysis.csv', index=False)
